# %% [markdown]
# # Exercise II - Matplotlib
# Use the Big-Mart Data for some plotting exercises

# %%
#import an read big-mart data
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

data = pd.read_csv("company_sales_data.csv")

# %%
#short preview of the data table
data.head()
# Out:
#    month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0             1       2500      1500        5200         9200     1200
# 1             2       2630      1200        5100         6100     2100
# 2             3       2140      1340        4550         9550     3550
# 3             4       3400      1130        5870         8870     1870
# 4             5       3600      1740        4560         7760     1560
#
#    moisturizer  total_units  total_profit
# 0         1500        21100        211000
# 1         1200        18330        183300
# 2         1340        22470        224700
# 3         1130        22270        222700
# 4         1740        20960        209600

# %%
#access data rows by name
plt.plot(data.toothpaste)

# %% [markdown]
# ## Exercise 1
# Read Total profit of all months and show it using a line plot
# Total profit data provided for each month. Generated line plot must include the following properties:
#
# * X label name = Month Number
# * Y label name = Total profit

# %%
#By: Amoah Stefan Ababio(ENITS 1)

plt.plot(data.month_number,data.total_profit)
plt.xlabel('Month Number')
plt.ylabel('Total Profit')
# Out:
# Text(0, 0.5, 'Total Profit')

# %% [markdown]
# ## Exercise 2
# Get Total profit of all months and show line plot with the following Style properties
# Generated line plot must include following Style properties:
#
# * Line Style dotted and Line color should be red
# * Show legend at the lower right location.
# * X label name = Month Number
# * Y label name = Sold units number
# * Add a circle marker.
# * Line marker color as read
# * Line width should be 3

# %%
plt.plot(data.total_profit, linestyle='dotted', c='red', marker='o',linewidth=3, label='Sold units number') 
plt.xlabel('Month Number')
plt.ylabel('Sold units number')
plt.legend(loc='lower right')

# %% [markdown]
# ## Exercise 3
# Read all product sales data and show it  using a multiline plot
# Display the number of units sold per month for each product using multiline plots. (i.e., Separate Plotline for each product for each product).

# %%
plt.plot(data['facecream'])
plt.plot(data['facewash'])
plt.plot(data['toothpaste'])
plt.plot(data['bathingsoap'])
plt.plot(data['shampoo'])
plt.plot(data['moisturizer'])

# %% [markdown]
# ## Exercise 4
# Read toothpaste sales data of each month and show it using a scatter plot
# Also, add a grid in the plot.

# %%
plt.scatter(data.month_number,data.toothpaste, label='toothpaste')
plt.grid()
plt.legend()

# %% [markdown]
# ## Exercise 5
# Read face cream and facewash product sales data and show it using the bar chart
# Bar chart should display the number of units sold per month for each product. Add a separate bar for each product in the same chart.

# %%
plt.bar(data.month_number, data.facecream, label ='face cream')
plt.bar(data.month_number, data.facewash, label ='face cream')
plt.legend()

# %% [markdown]
# ## Exercise 6
# Calculate total sale data for last year for each product and show it using a Pie chart
# Note: In Pie chart display Number of units sold per year for each product in percentage.
#
# ***Note:*** use ``data[item].sum()`` to compute sums over columns

# %%
data['toothpaste'].sum()
# Out:
# 69910

# %%
pie_values =[
    data['facecream'].sum(),
    data['facewash'].sum(),
    data['toothpaste'].sum(),
    data['shampoo'].sum(),
    data['bathingsoap'].sum(),
    
    data['moisturizer'].sum()
]

# %%
plt.pie(pie_values, labels=['facecream', 'facewash','toothpaste','bathingsoap','shampoo','moisturiser'],autopct='%1.2f%%');

# %%
;
# Out:
# ''
